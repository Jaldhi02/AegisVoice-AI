# %% [markdown]
# # AI Voice Fraud Detection & Prevention System - Exploration
#
# This notebook provides interactive exploration of:
# 1. **Audio Feature Extraction** (MFCCs, Spectral Centroid, Zero Crossing Rate, Jitter, Shimmer)
# 2. **Voice Clone Detection** (Synthetic vs. Genuine Voice Classifier)
# 3. **Scam Intent Detection** (NLP Coercion & Urgency Trigger Analysis)
# 4. **Composite Risk Engine** (Risk Score 0-100 and Alert Evaluation)

# %%
import sys
import os
sys.path.append(os.path.abspath('..'))

from preprocessing.audio_preprocessing import AudioPreprocessor
from preprocessing.feature_extraction import AudioFeatureExtractor
from preprocessing.text_preprocessing import TextPreprocessor
from inference.voice_detector import VoiceDetector
from inference.scam_detector import ScamDetector
from inference.risk_engine import RiskEngine

# %%
# Initialize engines
engine = RiskEngine()
print("Risk Engine initialized successfully!")

# Sample test call
sample_text = "Immediate action required! Your bank account has been suspended. Please confirm your OTP and debit card PIN now."
result = engine.evaluate(text_transcript=sample_text)
print("Assessment Result:", result)
